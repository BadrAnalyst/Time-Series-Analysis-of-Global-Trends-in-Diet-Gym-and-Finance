# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv(r"C:\Users\Utilisateur\Desktop\Daten 2024-25\D.A Mustafa Othman\multiTimeline.csv",skiprows=1)
df.head()
# Out:
#          Jour  diet: (Dans tous les pays)  gym: (Dans tous les pays)  \
# 0  2021-04-23                          44                         55
# 1  2021-04-24                          47                         54
# 2  2021-04-25                          50                         58
# 3  2021-04-26                          48                         62
# 4  2021-04-27                          48                         63
#
#    finance: (Dans tous les pays)
# 0                             80
# 1                             49
# 2                             45
# 3                             87
# 4                             80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Jour                           29 non-null     object
#  1   diet: (Dans tous les pays)     29 non-null     int64
#  2   gym: (Dans tous les pays)      29 non-null     int64
#  3   finance: (Dans tous les pays)  29 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.0+ KB

# %% [markdown]
# ## Wrangle Data

# %%
df.columns = ['Day','Diet','Gym','Finance']
df.head()
# Out:
#           Day  Diet  Gym  Finance
# 0  2021-04-23    44   55       80
# 1  2021-04-24    47   54       49
# 2  2021-04-25    50   58       45
# 3  2021-04-26    48   62       87
# 4  2021-04-27    48   63       80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Day      29 non-null     object
#  1   Diet     29 non-null     int64
#  2   Gym      29 non-null     int64
#  3   Finance  29 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.0+ KB

# %%
df['Day'] = pd.to_datetime(df['Day'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Day      29 non-null     datetime64[ns]
#  1   Diet     29 non-null     int64
#  2   Gym      29 non-null     int64
#  3   Finance  29 non-null     int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 1.0 KB

# %%
df.set_index('Day',inplace=True)
df.head()
# Out:
#             Diet  Gym  Finance
# Day
# 2021-04-23    44   55       80
# 2021-04-24    47   54       49
# 2021-04-25    50   58       45
# 2021-04-26    48   62       87
# 2021-04-27    48   63       80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29 entries, 2021-04-23 to 2021-05-21
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Diet     29 non-null     int64
#  1   Gym      29 non-null     int64
#  2   Finance  29 non-null     int64
# dtypes: int64(3)
# memory usage: 928.0 bytes

# %% [markdown]
# ## EDA

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
df[['Diet']].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Day'>

# %% [markdown]
# ## Trends & Seasonality Time Series Data

# %%
df[['Diet']].rolling(2).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
df[['Gym']].rolling(2).mean().plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
pd.concat([df[['Diet']].rolling(2).mean(),df[['Gym']].rolling(2).mean()], axis=1).plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Day'>
